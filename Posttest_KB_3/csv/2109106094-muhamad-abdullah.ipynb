# %%
import pandas as pd
from tabulate import tabulate
df = pd.concat(
    map(pd.read_csv, ['csv/MY2015 Fuel Consumption Ratings.csv', 'csv/MY2016 Fuel Consumption Ratings.csv']), ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2 from tabulate import tabulate
# ----> 3 df = pd.concat(
#       4     map(pd.read_csv, ['Desktop/nugas/abdullah_94/csv/MY2015 Fuel Consumption Ratings.csv', 'Desktop/nugas/abdullah_94/csv/MY2016 Fuel Consumption Ratings.csv']), ignore_index=True)
#
# File c:\Users\ADMIN\Desktop\nugas\abdullah_94\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\ADMIN\Desktop\nugas\abdullah_94\lib\site-packages\pandas\core\reshape\concat.py:347, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     143 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     144 def concat(
#     145     objs: Iterable[NDFrame] | Mapping[Hashable, NDFrame],
#    (...)
#     154     copy: bool = True,
#     155 ) -> DataFrame | Series:
#     156     """
#     157     Concatenate pandas objects along a particular axis with optional set logic
#     158     along the other axes.
#    (...)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#     350         ignore_index=ignore_index,
#     351         join=join,
#     352         keys=keys,
#     353         levels=levels,
#     354         names=names,
#     355         verify_integrity=verify_integrity,
#     356         copy=copy,
#     357         sort=sort,
#     358     )
#     360     return op.get_result()
#
# File c:\Users\ADMIN\Desktop\nugas\abdullah_94\lib\site-packages\pandas\core\reshape\concat.py:401, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     399     objs = [objs[k] for k in keys]
#     400 else:
# --> 401     objs = list(objs)
#     403 if len(objs) == 0:
#     404     raise ValueError("No objects to concatenate")
#
# File c:\Users\ADMIN\Desktop\nugas\abdullah_94\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\ADMIN\Desktop\nugas\abdullah_94\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\ADMIN\Desktop\nugas\abdullah_94\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Users\ADMIN\Desktop\nugas\abdullah_94\lib\site-packages\pandas\io\parsers\readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\ADMIN\Desktop\nugas\abdullah_94\lib\site-packages\pandas\io\parsers\readers.py:1218, in TextFileReader._make_engine(self, f, engine)
#    1214     mode = "rb"
#    1215 # error: No overload variant of "get_handle" matches argument types
#    1216 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218 self.handles = get_handle(  # type: ignore[call-overload]
#    1219     f,
#    1220     mode,
#    1221     encoding=self.options.get("encoding", None),
#    1222     compression=self.options.get("compression", None),
#    1223     memory_map=self.options.get("memory_map", False),
#    1224     is_text=is_text,
#    1225     errors=self.options.get("encoding_errors", "strict"),
#    1226     storage_options=self.options.get("storage_options", None),
#    1227 )
#    1228 assert self.handles is not None
#    1229 f = self.handles.handle
#
# File c:\Users\ADMIN\Desktop\nugas\abdullah_94\lib\site-packages\pandas\io\common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Desktop/nugas/abdullah_94/csv/MY2015 Fuel Consumption Ratings.csv'

# %% [markdown]
# import library dan mapping 2 csv

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %% [markdown]
# Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.

# %%
df[list(df.columns[df.dtypes == "float64"])].head(10)
# Out:
#    Engine Size (L)  Cylinders  Fuel Consumption (City) (L/100 km)  \
# 0              2.0        4.0                                 9.7
# 1              2.4        4.0                                10.8
# 2              1.5        4.0                                 6.0
# 3              3.5        6.0                                12.7
# 4              3.5        6.0                                12.1
# 5              3.5        6.0                                11.9
# 6              3.5        6.0                                 8.0
# 7              2.4        4.0                                 9.6
# 8              3.5        6.0                                11.2
# 9              3.5        6.0                                11.2
#
#    Fuel Consumption (Hwy) (L/100 km)  Fuel Consumption (Comb) (L/100 km)  \
# 0                                6.7                                 8.3
# 1                                7.4                                 9.3
# 2                                6.1                                 6.1
# 3                                9.1                                11.1
# 4                                8.7                                10.6
# 5                                7.7                                10.0
# 6                                7.5                                 7.7
# 7                                6.6                                 8.3
# 8                                6.9                                 9.2
# 9                                7.5                                 9.6
#
#    Fuel Consumption (Comb) (mpg)  CO2 Emissions (g/km)  CO2 Rating  \
# 0                           34.0                 191.0         NaN
# 1                           30.0                 214.0         NaN
# 2                           46.0                 140.0         NaN
# 3                           25.0                 255.0         NaN
# 4                           27.0                 244.0         NaN
# 5                           28.0                 230.0         NaN
# 6                           37.0                 177.0         NaN
# 7                           34.0                 191.0         NaN
# 8                           31.0                 212.0         NaN
# 9                           29.0                 221.0         NaN
#
#    Smog Rating
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN

# %% [markdown]
# Tampilkan 10 record pertama dari dataset dengan attribute bertipe angka.

# %%
dictBaru = {
    "banyak record" : [len(df)],
    "banyak atribute" : [len(df.columns)],
    "nama atribute" : ["\n".join(list(df.columns))],
    "banyak atribut angka" : [len(df.dtypes[df.dtypes == "float64"])],
}

print(tabulate(pd.DataFrame(dictBaru), headers="keys", tablefmt="psql", showindex=False))
# Out:
# +-----------------+-------------------+------------------------------------+------------------------+
# |   banyak record |   banyak atribute | nama atribute                      |   banyak atribut angka |
# |-----------------+-------------------+------------------------------------+------------------------|
# |            2290 |                15 | Year                               |                      9 |
# |                 |                   | Make                               |                        |
# |                 |                   | Model                              |                        |
# |                 |                   | Vehicle Class                      |                        |
# |                 |                   | Engine Size (L)                    |                        |
# |                 |                   | Cylinders                          |                        |
# |                 |                   | Transmission                       |                        |
# |                 |                   | Fuel Type                          |                        |
# |                 |                   | Fuel Consumption (City) (L/100 km) |                        |
# |                 |                   | Fuel Consumption (Hwy) (L/100 km)  |                        |
# |                 |                   | Fuel Consumption (Comb) (L/100 km) |                        |
# |                 |                   | Fuel Consumption (Comb) (mpg)      |                        |
# |                 |                   | CO2 Emissions (g/km)               |                        |
# |                 |                   | CO2 Rating                         |                        |
# |                 |                   | Smog Rating                        |                        |
# +-----------------+-------------------+------------------------------------+------------------------+

# %% [markdown]
# Tampilkan informasi jumlah record, jumlah attribute, nama attribute, jumlah attribute dengan tipe angka. Masukkan informasi tersebut dalam dictionary dengan key sesuai nama informasinya.

# %%
df.loc[94:len(df), "Engine Size (L)":"Smog Rating"]
# Out:
#       Engine Size (L)  Cylinders Transmission Fuel Type  \
# 94                2.0        4.0          AS8         D
# 95                2.0        4.0          AS8         Z
# 96                2.0        4.0           M6         Z
# 97                2.0        4.0          AS8         Z
# 98                2.0        4.0          AS8         Z
# ...               ...        ...          ...       ...
# 2285              NaN        NaN          NaN       NaN
# 2286              NaN        NaN          NaN       NaN
# 2287              NaN        NaN          NaN       NaN
# 2288              NaN        NaN          NaN       NaN
# 2289              NaN        NaN          NaN       NaN
#
#       Fuel Consumption (City) (L/100 km)  Fuel Consumption (Hwy) (L/100 km)  \
# 94                                   7.6                                5.5
# 95                                  10.0                                6.5
# 96                                  10.7                                6.9
# 97                                  10.6                                7.2
# 98                                  10.6                                7.2
# ...                                  ...                                ...
# 2285                                 NaN                                NaN
# 2286                                 NaN                                NaN
# 2287                                 NaN                                NaN
# 2288                                 NaN                                NaN
# 2289                                 NaN                                NaN
#
#       Fuel Consumption (Comb) (L/100 km)  Fuel Consumption (Comb) (mpg)  \
# 94                                   6.7                           42.0
# 95                                   8.4                           34.0
# 96                                   9.0                           31.0
# 97                                   9.1                           31.0
# 98                                   9.1                           31.0
# ...                                  ...                            ...
# 2285                                 NaN                            NaN
# 2286                                 NaN                            NaN
# 2287                                 NaN                            NaN
# 2288                                 NaN                            NaN
# 2289                                 NaN                            NaN
#
#       CO2 Emissions (g/km)  CO2 Rating  Smog Rating
# 94                   181.0         NaN          NaN
# 95                   193.0         NaN          NaN
# 96                   207.0         NaN          NaN
# 97                   209.0         NaN          NaN
# 98                   209.0         NaN          NaN
# ...                    ...         ...          ...
# 2285                   NaN         NaN          NaN
# 2286                   NaN         NaN          NaN
# 2287                   NaN         NaN          NaN
# 2288                   NaN         NaN          NaN
# 2289                   NaN         NaN          NaN
#
# [2196 rows x 11 columns]

# %% [markdown]
# Tampilkan nilai dataset pada baris dimulai dengan 3 digit NIM akhir hingga data terakhir dan kolom ke 4 hingga kolom terakhir menggunakan ke 2 metode slice

# %%
df.iloc[94:len(df), 4:15]
# Out:
#       Engine Size (L)  Cylinders Transmission Fuel Type  \
# 94                2.0        4.0          AS8         D
# 95                2.0        4.0          AS8         Z
# 96                2.0        4.0           M6         Z
# 97                2.0        4.0          AS8         Z
# 98                2.0        4.0          AS8         Z
# ...               ...        ...          ...       ...
# 2285              NaN        NaN          NaN       NaN
# 2286              NaN        NaN          NaN       NaN
# 2287              NaN        NaN          NaN       NaN
# 2288              NaN        NaN          NaN       NaN
# 2289              NaN        NaN          NaN       NaN
#
#       Fuel Consumption (City) (L/100 km)  Fuel Consumption (Hwy) (L/100 km)  \
# 94                                   7.6                                5.5
# 95                                  10.0                                6.5
# 96                                  10.7                                6.9
# 97                                  10.6                                7.2
# 98                                  10.6                                7.2
# ...                                  ...                                ...
# 2285                                 NaN                                NaN
# 2286                                 NaN                                NaN
# 2287                                 NaN                                NaN
# 2288                                 NaN                                NaN
# 2289                                 NaN                                NaN
#
#       Fuel Consumption (Comb) (L/100 km)  Fuel Consumption (Comb) (mpg)  \
# 94                                   6.7                           42.0
# 95                                   8.4                           34.0
# 96                                   9.0                           31.0
# 97                                   9.1                           31.0
# 98                                   9.1                           31.0
# ...                                  ...                            ...
# 2285                                 NaN                            NaN
# 2286                                 NaN                            NaN
# 2287                                 NaN                            NaN
# 2288                                 NaN                            NaN
# 2289                                 NaN                            NaN
#
#       CO2 Emissions (g/km)  CO2 Rating  Smog Rating
# 94                   181.0         NaN          NaN
# 95                   193.0         NaN          NaN
# 96                   207.0         NaN          NaN
# 97                   209.0         NaN          NaN
# 98                   209.0         NaN          NaN
# ...                    ...         ...          ...
# 2285                   NaN         NaN          NaN
# 2286                   NaN         NaN          NaN
# 2287                   NaN         NaN          NaN
# 2288                   NaN         NaN          NaN
# 2289                   NaN         NaN          NaN
#
# [2196 rows x 11 columns]

# %% [markdown]
# Tampilkan nilai dataset pada baris dimulai dengan 3 digit NIM akhir hingga data terakhir dan kolom ke 4 hingga kolom terakhir menggunakan ke 2 metode slice

# %%
ok = 0
for i in list(df.columns[df.dtypes == "object"]):
    ok = ok + df[i].notnull().sum()
    
print(ok)
# Out:
# 13505

# %% [markdown]
# Tampilkan jumlah nilai dari semua attribute yang bernilai object tanpa null.

# %%
# Subset feature dan target
X = df.iloc[:,:-1] # Target
y = df.iloc[:,-1] # Feature
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print("Dimensi X_train : ", X_train.shape)
print("Dimensi X_train : ", X_test.shape)
print("Dimensi y_train : ", y_train.shape)
print("Dimensi y_test : ", y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       2 X = df.iloc[:,:-1] # Target
#       3 y = df.iloc[:,-1] # Feature
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#       5 print("Dimensi X_train : ", X_train.shape)
#       6 print("Dimensi X_train : ", X_test.shape)
#
# NameError: name 'train_test_split' is not defined

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
data = np.asarray([[100, 0.001],
[8, 0.05],
[50, 0.005],
[88, 0.07],])
ss = StandardScaler()
Scaled_data = ss.fit_transform(data)

# %%
print("Nilai Data Sebelum scaling : ")
print(data)
print("Nilai standar deviasi: ", np.std(data))
print("\n Nilai Data setelah scaling : ")
print(Scaled_data)
print("Nilai standar deviasi: ", np.std(Scaled_data))
# Out:
# Nilai Data Sebelum scaling :
# [[1.0e+02 1.0e-03]
#  [8.0e+00 5.0e-02]
#  [5.0e+01 5.0e-03]
#  [8.8e+01 7.0e-02]]
# Nilai standar deviasi:  39.89949316955668
#
#  Nilai Data setelah scaling :
# [[ 1.06996056 -1.03748098]
#  [-1.48682831  0.62929174]
#  [-0.31959861 -0.9014179 ]
#  [ 0.73646636  1.30960714]]
# Nilai standar deviasi:  1.0

# %%
from sklearn.impute import SimpleImputer

# %%
# df.iloc[0:,0:12]
df.dropna(subset=['Vehicle Class'],inplace = True)
df.isna().any()
# .dropna(inplace = True)
# df.iloc[0:,0:12].isna().any()
# Out:
# Year                                  False
# Make                                  False
# Model                                 False
# Vehicle Class                         False
# Engine Size (L)                       False
# Cylinders                             False
# Transmission                          False
# Fuel Type                             False
# Fuel Consumption (City) (L/100 km)    False
# Fuel Consumption (Hwy) (L/100 km)     False
# Fuel Consumption (Comb) (L/100 km)    False
# Fuel Consumption (Comb) (mpg)         False
# CO2 Emissions (g/km)                  False
# CO2 Rating                             True
# Smog Rating                            True
# dtype: bool

# %%
# df.set_index('Vehicle Class')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2242 entries, 0 to 2262
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Year                                2242 non-null   object
#  1   Make                                2242 non-null   object
#  2   Model                               2242 non-null   object
#  3   Vehicle Class                       2242 non-null   object
#  4   Engine Size (L)                     2242 non-null   float64
#  5   Cylinders                           2242 non-null   float64
#  6   Transmission                        2242 non-null   object
#  7   Fuel Type                           2242 non-null   object
#  8   Fuel Consumption (City) (L/100 km)  2242 non-null   float64
#  9   Fuel Consumption (Hwy) (L/100 km)   2242 non-null   float64
#  10  Fuel Consumption (Comb) (L/100 km)  2242 non-null   float64
#  11  Fuel Consumption (Comb) (mpg)       2242 non-null   float64
#  12  CO2 Emissions (g/km)                2242 non-null   float64
#  13  CO2 Rating                          1110 non-null   float64
#  14  Smog Rating                         0 non-null      float64
# dtypes: float64(9), object(6)
# memory usage: 280.2+ KB

# %%
import matplotlib.pyplot as plt
# df
# datax =
datax = df.loc[0:,["Vehicle Class","Engine Size (L)","Cylinders","Fuel Consumption (City) (L/100 km)","Fuel Consumption (Hwy) (L/100 km)","Fuel Consumption (Comb) (L/100 km)","Fuel Consumption (Comb) (mpg)","CO2 Emissions (g/km)"]]
datap= datax.groupby("Vehicle Class").mean()
datap


x = (range(len(datap)))
new_x = [2*i for i in x]

# you might have to increase the size of the figure
plt.figure(figsize=(45, 25))  # width:10, height:8




x= datap.index
y = datap.Cylinders

plt.bar(x, y, align='center', width=0.5)
# plt.bar(x,y,color="green", width=0.5)



plt.title("rata2 cilinder kendaraan")
plt.xlabel('kelas kendaraan')
plt.ylabel("bedasar isi")
plt.show()
# .groupby('Vehicle Class').mean()
# datax
# x= df.index
# y = datax.SepalLengthCm

# plt.bar(x,y,color=['green', 'blue', 'yellow'])
# plt.title('rata-rata panjang sepal')
# plt.xlabel("jenis data")
# plt.ylabel("panjang rata2 sepal")

# plt.show()
